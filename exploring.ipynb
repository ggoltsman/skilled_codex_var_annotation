# %%
import duckdb

# %%
# Connect to an in-memory database instance
con = duckdb.connect()

# Print the table schema directly to the console
result = con.execute("DESCRIBE SELECT * FROM 'data/synthetic_gnomad.parquet';")
print(result.fetchall())
# Out:
# [('chrom', 'VARCHAR', 'YES', None, None, None), ('pos', 'BIGINT', 'YES', None, None, None), ('ref', 'VARCHAR', 'YES', None, None, None), ('alt', 'VARCHAR', 'YES', None, None, None), ('allele_frequency', 'DOUBLE', 'YES', None, None, None), ('allele_count', 'BIGINT', 'YES', None, None, None), ('allele_number', 'BIGINT', 'YES', None, None, None), ('popmax', 'VARCHAR', 'YES', None, None, None)]
